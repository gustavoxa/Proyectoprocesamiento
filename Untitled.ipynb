# %% [markdown]
# # Escuela Politécnica Nacional
# ### Proyecto N° 1
# ### Integrantes
# #### Carlos Vasquez
# #### Gustavo Aconda

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Datasetproyecto.csv",header=None)
df=df.drop([0],axis=0);

# %%
df.head()
# Out:
#                                        0  1     2      3       4      5  6  7  \
# 1  ANALISTA DE GESTION DE ABASTECIMIENTO  3  1755  21060  146.25  31.25  0  0
# 2       SUPERINTENDENTE DE MANTENIMIENTO  6  5250  63000   437.5  31.25  0  0
# 3                        SUPERVISOR RCRS  5  3300  39600     275  31.25  0  0
# 4                              MENSAJERO  1   962  11544   80.17  31.25  0  0
# 5                  AUXILIAR DE CAFETERIA  1   779   9348   64.92  31.25  0  0
#
#         8
# 1   177.5
# 2  468.75
# 3  306.25
# 4  111.42
# 5   96.17

# %%
df.shape
# Out:
# (10279, 9)

# %%
df.columns=["PuestoInstitucional","Gradojerarquicooescalaalqueperteneceelpuesto","Remuneracionmensualunificada","Remuneracionunificadaanual","DecimoTerceraRemuneracion","DecimaCuartaRemuneracion","Horassuplementariasyextraordinarias","Encargosysubrogaciones","Totalingresosadicionales"]

# %%
df.head()
# Out:
#                      PuestoInstitucional  \
# 1  ANALISTA DE GESTION DE ABASTECIMIENTO
# 2       SUPERINTENDENTE DE MANTENIMIENTO
# 3                        SUPERVISOR RCRS
# 4                              MENSAJERO
# 5                  AUXILIAR DE CAFETERIA
#
#   Gradojerarquicooescalaalqueperteneceelpuesto Remuneracionmensualunificada  \
# 1                                            3                         1755
# 2                                            6                         5250
# 3                                            5                         3300
# 4                                            1                          962
# 5                                            1                          779
#
#   Remuneracionunificadaanual DecimoTerceraRemuneracion  \
# 1                      21060                    146.25
# 2                      63000                     437.5
# 3                      39600                       275
# 4                      11544                     80.17
# 5                       9348                     64.92
#
#   DecimaCuartaRemuneracion Horassuplementariasyextraordinarias  \
# 1                    31.25                                   0
# 2                    31.25                                   0
# 3                    31.25                                   0
# 4                    31.25                                   0
# 5                    31.25                                   0
#
#   Encargosysubrogaciones Totalingresosadicionales
# 1                      0                    177.5
# 2                      0                   468.75
# 3                      0                   306.25
# 4                      0                   111.42
# 5                      0                    96.17

# %%
df.dtypes
# Out:
# PuestoInstitucional                             object
# Gradojerarquicooescalaalqueperteneceelpuesto    object
# Remuneracionmensualunificada                    object
# Remuneracionunificadaanual                      object
# DecimoTerceraRemuneracion                       object
# DecimaCuartaRemuneracion                        object
# Horassuplementariasyextraordinarias             object
# Encargosysubrogaciones                          object
# Totalingresosadicionales                        object
# dtype: object

# %%
df["Gradojerarquicooescalaalqueperteneceelpuesto"]=df["Gradojerarquicooescalaalqueperteneceelpuesto"].apply(pd.to_numeric)

# %%
df["Remuneracionmensualunificada"]=df["Remuneracionmensualunificada"].astype(float)
df["Remuneracionunificadaanual"]=df["Remuneracionunificadaanual"].astype(float)
df["DecimoTerceraRemuneracion"]=df["DecimoTerceraRemuneracion"].astype(float)
df["DecimaCuartaRemuneracion"]=df["DecimaCuartaRemuneracion"].astype(float)
df["Horassuplementariasyextraordinarias"]=df["Horassuplementariasyextraordinarias"].astype(float)
df["Encargosysubrogaciones"]=df["Encargosysubrogaciones"].astype(float)
df["Totalingresosadicionales"]=df["Totalingresosadicionales"].astype(float)

# %%
df.dtypes
# Out:
# PuestoInstitucional                              object
# Gradojerarquicooescalaalqueperteneceelpuesto      int64
# Remuneracionmensualunificada                    float64
# Remuneracionunificadaanual                      float64
# DecimoTerceraRemuneracion                       float64
# DecimaCuartaRemuneracion                        float64
# Horassuplementariasyextraordinarias             float64
# Encargosysubrogaciones                          float64
# Totalingresosadicionales                        float64
# dtype: object

# %%
df.head(20)
# Out:
#                          PuestoInstitucional  \
# 1      ANALISTA DE GESTION DE ABASTECIMIENTO
# 2           SUPERINTENDENTE DE MANTENIMIENTO
# 3                            SUPERVISOR RCRS
# 4                                  MENSAJERO
# 5                      AUXILIAR DE CAFETERIA
# 6                      AUXILIAR DE CAFETERIA
# 7                                  MENSAJERO
# 8                JEFE DE CONTROL DE QUIMICOS
# 9                   ASISTENTE ADMINISTRATIVA
# 10                      ASISTENTE DE ARCHIVO
# 11                      ASISTENTE DE ARCHIVO
# 12                             JEFE DE CAMPO
# 13                              RESERVORISTA
# 14  TÉCNICO ELÉCTRICO (PLANTA DE GENERACIÓN)
# 15         INGENIERO DE CORROSIÓN Y QUÍMICOS
# 16             SUPERVISOR DE INSTRUMENTACIÓN
# 17             SUPERINTENDENTE DE RCRS ( E )
# 18                                 BODEGUERO
# 19     SUPERINTENDENTE DE OPERACIONES  ( S )
# 20              SUPERINTENDENTE DE SEGURIDAD
#
#     Gradojerarquicooescalaalqueperteneceelpuesto  \
# 1                                              3
# 2                                              6
# 3                                              5
# 4                                              1
# 5                                              1
# 6                                              1
# 7                                              1
# 8                                              6
# 9                                              2
# 10                                             2
# 11                                             2
# 12                                             7
# 13                                             5
# 14                                             3
# 15                                             5
# 16                                             5
# 17                                             6
# 18                                             2
# 19                                             6
# 20                                             5
#
#     Remuneracionmensualunificada  Remuneracionunificadaanual  \
# 1                        1755.00                     21060.0
# 2                        5250.00                     63000.0
# 3                        3300.00                     39600.0
# 4                         962.00                     11544.0
# 5                         779.00                      9348.0
# 6                         784.00                      9408.0
# 7                         784.00                      9408.0
# 8                        6146.00                     73752.0
# 9                        1100.00                     13200.0
# 10                       1131.00                     13572.0
# 11                       1284.00                     15408.0
# 12                       6100.00                     73200.0
# 13                       4213.65                     50563.8
# 14                       2257.00                     27084.0
# 15                       3217.00                     38604.0
# 16                       4097.00                     49164.0
# 17                       3849.00                     46188.0
# 18                       1418.00                     17016.0
# 19                       3360.00                     40320.0
# 20                       4361.00                     52332.0
#
#     DecimoTerceraRemuneracion  DecimaCuartaRemuneracion  \
# 1                      146.25                     31.25
# 2                      437.50                     31.25
# 3                      275.00                     31.25
# 4                       80.17                     31.25
# 5                       64.92                     31.25
# 6                       65.33                     31.25
# 7                       65.33                     31.25
# 8                      512.17                     31.25
# 9                       91.67                     31.25
# 10                      94.25                     31.25
# 11                     107.00                     31.25
# 12                     508.33                     31.25
# 13                     351.14                     31.25
# 14                     188.08                     31.25
# 15                     268.08                     31.25
# 16                     357.78                     31.25
# 17                     320.75                     31.25
# 18                     124.08                     31.25
# 19                     280.00                     31.25
# 20                     363.42                     31.25
#
#     Horassuplementariasyextraordinarias  Encargosysubrogaciones  \
# 1                                  0.00                     0.0
# 2                                  0.00                     0.0
# 3                                  0.00                     0.0
# 4                                  0.00                     0.0
# 5                                  0.00                     0.0
# 6                                  0.00                     0.0
# 7                                  0.00                     0.0
# 8                                  0.00                     0.0
# 9                                  0.00                     0.0
# 10                                 0.00                     0.0
# 11                                 0.00                     0.0
# 12                                 0.00                     0.0
# 13                                 0.00                     0.0
# 14                                 0.00                     0.0
# 15                                 0.00                     0.0
# 16                               196.31                     0.0
# 17                                 0.00                   512.0
# 18                                70.90                     0.0
# 19                                 0.00                  1607.0
# 20                                 0.00                     0.0
#
#     Totalingresosadicionales
# 1                     177.50
# 2                     468.75
# 3                     306.25
# 4                     111.42
# 5                      96.17
# 6                      96.58
# 7                      96.58
# 8                     543.42
# 9                     122.92
# 10                    125.50
# 11                    138.25
# 12                    539.58
# 13                    382.39
# 14                    219.33
# 15                    299.33
# 16                    585.34
# 17                    864.00
# 18                    226.23
# 19                   1918.25
# 20                    394.67

# %%
df.describe()
# Out:
#        Gradojerarquicooescalaalqueperteneceelpuesto  \
# count                                  10279.000000
# mean                                       2.781302
# std                                        1.596490
# min                                        1.000000
# 25%                                        1.000000
# 50%                                        3.000000
# 75%                                        4.000000
# max                                        8.000000
#
#        Remuneracionmensualunificada  Remuneracionunificadaanual  \
# count                  10279.000000                10279.000000
# mean                    1402.891533                16834.698399
# std                     1072.061428                12864.737132
# min                      465.000000                 5580.000000
# 25%                      574.000000                 6888.000000
# 50%                     1087.000000                13044.000000
# 75%                     1886.150000                22633.800000
# max                     8437.500000               101250.000000
#
#        DecimoTerceraRemuneracion  DecimaCuartaRemuneracion  \
# count               10279.000000              10279.000000
# mean                  120.846929                 31.239157
# std                    91.984632                  0.346929
# min                    37.460000                 15.620000
# 25%                    48.420000                 31.250000
# 50%                    91.370000                 31.250000
# 75%                   164.250000                 31.250000
# max                   703.120000                 31.250000
#
#        Horassuplementariasyextraordinarias  Encargosysubrogaciones  \
# count                         10279.000000            10279.000000
# mean                             46.754803               89.465466
# std                             149.552388              282.027540
# min                               0.000000             -641.420000
# 25%                               0.000000                0.000000
# 50%                               0.000000                0.000000
# 75%                              20.290000                0.000000
# max                            2844.980000             5284.000000
#
#        Totalingresosadicionales
# count              10279.000000
# mean                 288.306355
# std                  337.438746
# min                 -473.360000
# 25%                   97.580000
# 50%                  197.830000
# 75%                  311.900000
# max                 5391.580000

# %%
df.corr()
# Out:
#                                               Gradojerarquicooescalaalqueperteneceelpuesto  \
# Gradojerarquicooescalaalqueperteneceelpuesto                                      1.000000
# Remuneracionmensualunificada                                                      0.794999
# Remuneracionunificadaanual                                                        0.794999
# DecimoTerceraRemuneracion                                                         0.792869
# DecimaCuartaRemuneracion                                                         -0.014161
# Horassuplementariasyextraordinarias                                               0.144321
# Encargosysubrogaciones                                                            0.337534
# Totalingresosadicionales                                                          0.562189
#
#                                               Remuneracionmensualunificada  \
# Gradojerarquicooescalaalqueperteneceelpuesto                      0.794999
# Remuneracionmensualunificada                                      1.000000
# Remuneracionunificadaanual                                        1.000000
# DecimoTerceraRemuneracion                                         0.989889
# DecimaCuartaRemuneracion                                         -0.009766
# Horassuplementariasyextraordinarias                               0.126527
# Encargosysubrogaciones                                            0.002470
# Totalingresosadicionales                                          0.327971
#
#                                               Remuneracionunificadaanual  \
# Gradojerarquicooescalaalqueperteneceelpuesto                    0.794999
# Remuneracionmensualunificada                                    1.000000
# Remuneracionunificadaanual                                      1.000000
# DecimoTerceraRemuneracion                                       0.989889
# DecimaCuartaRemuneracion                                       -0.009766
# Horassuplementariasyextraordinarias                             0.126527
# Encargosysubrogaciones                                          0.002470
# Totalingresosadicionales                                        0.327971
#
#                                               DecimoTerceraRemuneracion  \
# Gradojerarquicooescalaalqueperteneceelpuesto                   0.792869
# Remuneracionmensualunificada                                   0.989889
# Remuneracionunificadaanual                                     0.989889
# DecimoTerceraRemuneracion                                      1.000000
# DecimaCuartaRemuneracion                                       0.009502
# Horassuplementariasyextraordinarias                            0.258894
# Encargosysubrogaciones                                        -0.003318
# Totalingresosadicionales                                       0.384575
#
#                                               DecimaCuartaRemuneracion  \
# Gradojerarquicooescalaalqueperteneceelpuesto                 -0.014161
# Remuneracionmensualunificada                                 -0.009766
# Remuneracionunificadaanual                                   -0.009766
# DecimoTerceraRemuneracion                                     0.009502
# DecimaCuartaRemuneracion                                      1.000000
# Horassuplementariasyextraordinarias                           0.009772
# Encargosysubrogaciones                                        0.009916
# Totalingresosadicionales                                      0.016237
#
#                                               Horassuplementariasyextraordinarias  \
# Gradojerarquicooescalaalqueperteneceelpuesto                             0.144321
# Remuneracionmensualunificada                                             0.126527
# Remuneracionunificadaanual                                               0.126527
# DecimoTerceraRemuneracion                                                0.258894
# DecimaCuartaRemuneracion                                                 0.009772
# Horassuplementariasyextraordinarias                                      1.000000
# Encargosysubrogaciones                                                  -0.040972
# Totalingresosadicionales                                                 0.479538
#
#                                               Encargosysubrogaciones  \
# Gradojerarquicooescalaalqueperteneceelpuesto                0.337534
# Remuneracionmensualunificada                                0.002470
# Remuneracionunificadaanual                                  0.002470
# DecimoTerceraRemuneracion                                  -0.003318
# DecimaCuartaRemuneracion                                    0.009916
# Horassuplementariasyextraordinarias                        -0.040972
# Encargosysubrogaciones                                      1.000000
# Totalingresosadicionales                                    0.816736
#
#                                               Totalingresosadicionales
# Gradojerarquicooescalaalqueperteneceelpuesto                  0.562189
# Remuneracionmensualunificada                                  0.327971
# Remuneracionunificadaanual                                    0.327971
# DecimoTerceraRemuneracion                                     0.384575
# DecimaCuartaRemuneracion                                      0.016237
# Horassuplementariasyextraordinarias                           0.479538
# Encargosysubrogaciones                                        0.816736
# Totalingresosadicionales                                      1.000000

# %% [markdown]
# ### Para la realización del proyecto y poder aprender más sobre como funcionan los algoritmos se decidio tomar los valores que no tengan un alto valor de correlación

# %% [markdown]
# # Regresión Lineal

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x=np.asarray(df[["Totalingresosadicionales","Gradojerarquicooescalaalqueperteneceelpuesto","Horassuplementariasyextraordinarias"]])
y=np.asarray(df["Remuneracionunificadaanual"])

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.70,test_size=0.30,random_state=101)

# %%
print("Conjunto Entrenamiento :", xtrain.shape,ytrain.shape)
print("conjunto Prueba: ",xtest.shape,ytest.shape)
# Out:
# Conjunto Entrenamiento : (7195, 3) (7195,)
# conjunto Prueba:  (3084, 3) (3084,)

# %%
lm=LinearRegression()

# %%
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
h=lm.predict(xtest)

# %%
h.size
# Out:
# 3084

# %%
from sklearn.metrics import mean_squared_error

# %%
mse2 = mean_squared_error(ytest,h)
print("el error cuadratico medio del precio y  hipotesis es :",mse2)
# Out:
# el error cuadratico medio del precio y  hipotesis es : 56293212.33206131

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
grafica=sns.distplot(ytrain,hist=False, color="r",label="Salida-Real")#precio real
sns.distplot(h,hist=False,color="b",label="Valores Estimados",ax=grafica)#hipotesis ax para que esten sobrelapadas

## si colocamos tRUE dibujamos barras 

#Detalles de etiquetado
plt.title("Valores reales ajustados a valores estimados")
plt.xlabel("precio")
plt.ylabel("porcion de carros")
plt.show()

# %%
## Valor mas alto
xa=np.asarray(df[["DecimoTerceraRemuneracion","DecimaCuartaRemuneracion"]])
ya=np.asarray(df["Remuneracionunificadaanual"])

# %%
xtraina,xtesta,ytraina,ytesta=train_test_split(xa,ya,train_size=0.70,test_size=0.30,random_state=101)

# %%
lma=LinearRegression()
lma.fit(xa,ya)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
ha=lma.predict(xtesta)

# %%
msea = mean_squared_error(ytesta,ha)
print("el error cuadratico medio del precio y  hipotesis es :",msea)
# Out:
# el error cuadratico medio del precio y  hipotesis es : 2965149.5635369816

# %%
grafica=sns.distplot(ytraina,hist=False, color="r",label="Salida-Real")#precio real
sns.distplot(ha,hist=False,color="b",label="Valores Estimados",ax=grafica)#hipotesis ax para que esten sobrelapadas

## si colocamos tRUE dibujamos barras 

#Detalles de etiquetado
plt.title("Valores reales ajustados a valores estimados")
plt.xlabel("precio")
plt.ylabel("porcion de carros")
plt.show()
